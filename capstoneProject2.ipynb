# %%
from pandas_datareader import data,wb
import pandas as pd
import seaborn as sns
import yfinance as yf
import numpy as np
import datetime
# %matplotlib inline

# %%
start= datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %%
BAC = yf.download('BAC', start='2006-01-01', end='2023-01-01') # here are some symbol of which we have created this dfs 
C= yf.download('C', start='2006-01-01', end='2023-01-01')
GS = yf.download('GS', start='2006-01-01', end='2023-01-01')
MS = yf.download('MS', start='2006-01-01', end='2023-01-01')
JPM= yf.download('JPM', start='2006-01-01', end='2023-01-01')
WFC = yf.download('WFC', start='2006-01-01', end='2023-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
tickers=['BAC','C','GS','MS','JPM','WFC']

# %%
banks_stocks = pd.concat([BAC,C,GS,MS,JPM,WFC],axis=1,keys=tickers) #here we created only on df for all

# %%
banks_stocks.head()
# Out:
#                   BAC                                                      C  \
# Price           Close       High        Low       Open    Volume       Close
# Ticker            BAC        BAC        BAC        BAC       BAC           C
# Date
# 2006-01-03  31.173668  31.239881  30.557875  31.067723  16296700  324.013153
# 2006-01-04  30.842600  31.279614  30.756521  31.120699  17757900  318.031097
# 2006-01-05  30.882328  31.008137  30.670443  30.842601  14970700  319.608795
# 2006-01-06  30.836002  31.061131  30.690330  30.988295  12599800  319.608795
# 2006-01-09  30.855856  31.100851  30.696943  30.935315  15619400  318.096863
#
#                                                          ...        JPM  \
# Price             High         Low        Open   Volume  ...      Close
# Ticker               C           C           C        C  ...        JPM
# Date                                                     ...
# ...

# %%
banks_stocks.columns.names=['Bank_Ticker','Stock_Info','Tickers']
# assigned then name to columns

# %%
banks_stocks.head()
# Out:
# Bank_Ticker        BAC                                                      C  \
# Stock_Info       Close       High        Low       Open    Volume       Close
# Tickers            BAC        BAC        BAC        BAC       BAC           C
# Date
# 2006-01-03   31.173668  31.239881  30.557875  31.067723  16296700  324.013153
# 2006-01-04   30.842600  31.279614  30.756521  31.120699  17757900  318.031097
# 2006-01-05   30.882328  31.008137  30.670443  30.842601  14970700  319.608795
# 2006-01-06   30.836002  31.061131  30.690330  30.988295  12599800  319.608795
# 2006-01-09   30.855856  31.100851  30.696943  30.935315  15619400  318.096863
#
# Bank_Ticker                                               ...        JPM  \
# Stock_Info         High         Low        Open   Volume  ...      Close
# Tickers               C           C           C        C  ...        JPM
# Date                                                      ...
# ...

# %%
banks_stocks.columns
banks_stocks.columns.nlevels
# Out:
# 3

# %%
for ticks in tickers:
    print(ticks,banks_stocks[ticks]['Close'].max()) #this code is to check high close for each symbol or ticker we can say
# Out:
# BAC Tickers
# BAC    45.351673
# dtype: float64
# C Tickers
# C    386.292786
# dtype: float64
# GS Tickers
# GS    386.83255
# dtype: float64
# MS Tickers
# MS    97.593277
# dtype: float64
# JPM Tickers
# JPM    157.121063
# dtype: float64
# WFC Tickers
# WFC    54.488708
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for ticks in tickers: #filling data in returns df only for close price
    returns[ticks+' Return']=banks_stocks[ticks]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  MS Return  JPM Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN        NaN         NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   0.000686   -0.005772   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000394   0.002742    0.003029   -0.001110
# 2006-01-06   -0.001500  0.000000   0.014169   0.001025    0.007046    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030   0.010586    0.016242   -0.000159

# %%
sns.pairplot(returns[1:]) #we get crash at MS stock some where

# %%
#we have check on which date each tickers has worst and best close prices 
returns.idxmin() #this function work on entier dataframe and we get worst close prices using min
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# MS Return    2008-10-09
# JPM Return   2009-01-20
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax() #this function work on entier dataframe and we get best close prices using max
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# MS Return    2008-10-13
# JPM Return   2009-01-21
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std() #this how we can also check standard deviation
# Out:
# BAC Return    0.031178
# C Return      0.032942
# GS Return     0.023073
# MS Return     0.031919
# JPM Return    0.024305
# WFC Return    0.026832
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std() #from that 1 year whole std for each ticker
# Out:
# BAC Return    0.016174
# C Return      0.015288
# GS Return     0.014043
# MS Return     0.016287
# JPM Return    0.014006
# WFC Return    0.012552
# dtype: float64

# %%
#using seaborn we have check displot for ms returns column
sns.displot(returns.loc['2015-01-01':'2015-12-31']['MS Return'],color='yellow',bins=50)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')  # Corrected style



import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %%
# %matplotlib inline

# %%
for ticks in tickers:
    banks_stocks[ticks]['Close'].plot(label=ticks,figsize=(12,4))
    plt.legend()

# %%
banks_stocks.xs(key='Close', axis=1, level='Stock_Info').plot() #to check the stockinfo for each stock close price
# Out:
# <Axes: xlabel='Date'>

# %%
BAC['Close'].loc['2015-01-01':'2015-12-31'].rolling(window=30).mean().plot(label='AVG')#to plot the avg of 30 days 
BAC['Close'].loc['2015-01-01':'2015-12-31'].plot(label='BAC Close')

plt.legend()  # Show legend
plt.show()  # Display the plot

# %%
sns.heatmap(banks_stocks.xs(key='Close', axis=1, level='Stock_Info').corr(),annot=True)  # Added closing parenthesis
plt.show()  # Optional: Display the heatmap

# %%
close_corr= banks_stocks.xs(key='Close', axis=1, level='Stock_Info').corr()
close_corr.iplot(kind='heatmap')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 2
#       1 close_corr= banks_stocks.xs(key='Close', axis=1, level='Stock_Info').corr()
# ----> 2 close_corr.iplot(kind='heatmap')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\cufflinks\plotlytools.py:1216, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
# ...
